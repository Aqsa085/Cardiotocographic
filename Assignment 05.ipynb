# %% [markdown]
# ## 01.Data Cleaning & Preparation

# %%
#import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# c:\Users\Aqsa\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv('Cardiotocographic.csv')

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
df.shape #to know rows and columns
# Out:
# (2126, 14)

# %%
df.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %% [markdown]
# ## Missing values & Imputation

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# Create the imputer with 'mean' strategy
imputer = SimpleImputer(strategy='mean')

# %%
# Set up the imputer to replace missing values with the mean of each column
imputer = SimpleImputer(strategy='mean')

# Replace missing values in the DataFrame and update it with the new data
df = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
df[df.duplicated()].shape
# Out:
# (2, 14)

# %%
df[df.duplicated()]
# Out:
#          LB        AC   FM        UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  \
# 1115  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1458  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
#
#       Width  Tendency  NSP
# 1115   39.0       0.0  1.0
# 1458   35.0       0.0  1.0

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
# Convert all columns to numeric values, replace non-numeric values with NaN
df = df.apply(pd.to_numeric, errors='coerce')

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %% [markdown]
# ## Detect and Treat outliers

# %%
# Plot boxplot before treating outliers
plt.figure(figsize=(10,8))
df.boxplot()
plt.title('Boxplot Before Handling Outliers')
plt.show()

# %%
def treat_outliers(df, column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    IQR = q3 - q1

    # Calculate the upper and lower limits for outliers
    upper_limit = q3 + 1.5 * IQR
    lower_limit = q1 - 1.5 * IQR

    # Clip values to the limits
    df[column] = df[column].clip(lower=lower_limit, upper=upper_limit)

    return df

# %%
# Detect and treat outliers for each column
for column in df.columns:
    df = treat_outliers(df, column)

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.006416  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV  ALTV  MLTV  Width  Tendency  NSP
# 0      0.5  27.5   2.4   64.0  0.999926  1.0
# ...

# %%
# Plot boxplot after treating outliers
plt.figure(figsize=(10,8))
df.boxplot()
plt.title('Boxplot After Treating Outliers')
plt.show()

# %% [markdown]
# ## 02.Statistical Summary

# %%
summary = df.describe()
# Transpose the summary so that rows become columns and vice versa
summary = summary.T

# %%
summary
# Out:
#            count        mean        std         min         25%         50%  \
# LB        2126.0  133.293725   9.930227  105.000000  126.000000  133.000000
# AC        2126.0    0.003147   0.003826   -0.008409    0.000000    0.001668
# FM        2126.0    0.001568   0.002485   -0.003850    0.000000    0.000000
# UC        2126.0    0.004362   0.003001   -0.005177    0.001851    0.004484
# DL        2126.0    0.001770   0.002668   -0.004934    0.000000    0.000000
# DS        2126.0    0.000000   0.000000    0.000000    0.000000    0.000000
# DP        2126.0    0.000000   0.000000    0.000000    0.000000    0.000000
# ASTV      2126.0   46.981873  17.612745  -11.500000   32.000000   49.000000
# MSTV      2126.0    1.304644   0.781091   -0.800000    0.700000    1.200000
# ALTV      2126.0    6.691678  10.378400  -16.500000    0.000000    0.000000
# MLTV      2126.0    8.016212   5.046784   -4.700000    4.600000    7.500000
# ...

# %%
summary['median']=df.median()
summary
# Out:
#            count        mean        std         min         25%         50%  \
# LB        2126.0  133.293725   9.930227  105.000000  126.000000  133.000000
# AC        2126.0    0.003147   0.003826   -0.008409    0.000000    0.001668
# FM        2126.0    0.001568   0.002485   -0.003850    0.000000    0.000000
# UC        2126.0    0.004362   0.003001   -0.005177    0.001851    0.004484
# DL        2126.0    0.001770   0.002668   -0.004934    0.000000    0.000000
# DS        2126.0    0.000000   0.000000    0.000000    0.000000    0.000000
# DP        2126.0    0.000000   0.000000    0.000000    0.000000    0.000000
# ASTV      2126.0   46.981873  17.612745  -11.500000   32.000000   49.000000
# MSTV      2126.0    1.304644   0.781091   -0.800000    0.700000    1.200000
# ALTV      2126.0    6.691678  10.378400  -16.500000    0.000000    0.000000
# MLTV      2126.0    8.016212   5.046784   -4.700000    4.600000    7.500000
# ...

# %%
summary['IQR'] =  df.quantile(0.75)-df.quantile(0.25)
summary
# Out:
#            count        mean        std         min         25%         50%  \
# LB        2126.0  133.293725   9.930227  105.000000  126.000000  133.000000
# AC        2126.0    0.003147   0.003826   -0.008409    0.000000    0.001668
# FM        2126.0    0.001568   0.002485   -0.003850    0.000000    0.000000
# UC        2126.0    0.004362   0.003001   -0.005177    0.001851    0.004484
# DL        2126.0    0.001770   0.002668   -0.004934    0.000000    0.000000
# DS        2126.0    0.000000   0.000000    0.000000    0.000000    0.000000
# DP        2126.0    0.000000   0.000000    0.000000    0.000000    0.000000
# ASTV      2126.0   46.981873  17.612745  -11.500000   32.000000   49.000000
# MSTV      2126.0    1.304644   0.781091   -0.800000    0.700000    1.200000
# ALTV      2126.0    6.691678  10.378400  -16.500000    0.000000    0.000000
# MLTV      2126.0    8.016212   5.046784   -4.700000    4.600000    7.500000
# ...

# %% [markdown]
# ## Interesting Findings:
# Median vs. Mean:
# If the mean and median differ significantly in any column, it suggests the data might be skewed.
#
# IQR (Interquartile Range):
# A large IQR indicates wide data spread. Columns with high IQR values may have more variability.
# A small IQR suggests tightly packed data with little variation.
#
# Outliers:
# Columns where the mean is far from the 25th and 75th percentiles could indicate outliers pulling the mean.

# %% [markdown]
# The dataset contains 2,103 rows of fetal heart health data.
# The central tendency indicates that the data falls within a very narrow range.
# Out of 14 columns, 10 have a mean value greater than 10.
# Most columns show a narrow interquartile range (IQR).
# 9 columns have an IQR smaller than 1.
# 4 columns have an IQR smaller than 30.
# The baseline fetal heart rate (LB) is typically around 133 beats per minute.
# The medians of the columns are generally close to zero.

# %% [markdown]
# ## 03.Data Visualization

# %%
#Create Histogram
df.hist(bins=20, figsize=(30, 25),facecolor='blue',edgecolor='black')
plt.show()

# %%
#Create Boxplot
plt.figure(figsize=(20, 15))
sns.boxplot(data=df)
plt.show()

# %%
# Generate a correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, linewidths=0.5,cmap='Blues')
plt.title('Correlation Heatmap',fontsize=16)
plt.show()

# %%
# Create pair plots
sns.pairplot(df)
plt.suptitle('Pair Plot of All Variables', y=1.04)
plt.show()
# Out:
# c:\Users\Aqsa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Aqsa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Aqsa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
#Create Violin Plots
# Get the total number of columns (variables) in the DataFrame
num_vars = len(df.columns)

# Set the number of columns for the plot grid
num_cols = 4

# Calculate how many rows we need based on the number of variables
num_rows = (num_vars + num_cols - 1) // num_cols

# Set the size of the overall figure (adjusting height based on rows)
plt.figure(figsize=(12, 6* num_rows))

# Loop through each column and create a violin plot for it
for i, column in enumerate(df.columns):
    plt.subplot(num_rows, num_cols, i + 1)  # Create subplot for each variable
    sns.violinplot(y=df[column])  # Create a violin plot for the current variable
    plt.title(column)  # Set the title as the column name

plt.tight_layout()  # Adjust layout to avoid overlapping
plt.show()  # Display the plots

# %% [markdown]
# ## 04. Pattern Recognition and insights

# %%
# Calculate correlation matrix
correlation_matrix = df.corr()

# %%
correlation_matrix
# Out:
#                 LB        AC        FM        UC        DL  DS  DP      ASTV  \
# LB        1.000000 -0.080880 -0.006904 -0.162773 -0.156224 NaN NaN  0.285623
# AC       -0.080880  1.000000  0.076151  0.093970 -0.102722 NaN NaN -0.272436
# FM       -0.006904  0.076151  1.000000 -0.317265 -0.017610 NaN NaN  0.156351
# UC       -0.162773  0.093970 -0.317265  1.000000  0.268605 NaN NaN -0.215984
# DL       -0.156224 -0.102722 -0.017610  0.268605  1.000000 NaN NaN -0.111624
# DS             NaN       NaN       NaN       NaN       NaN NaN NaN       NaN
# DP             NaN       NaN       NaN       NaN       NaN NaN NaN       NaN
# ASTV      0.285623 -0.272436  0.156351 -0.215984 -0.111624 NaN NaN  1.000000
# MSTV     -0.295485  0.217447  0.070300  0.297843  0.566340 NaN NaN -0.433844
# ALTV      0.322315 -0.409592 -0.013420 -0.293340 -0.295886 NaN NaN  0.439040
# MLTV     -0.042613 -0.152335 -0.036875 -0.074002 -0.242556 NaN NaN -0.324728
# ...

# %% [markdown]
# ## Summary Report

# %% [markdown]
# ## Key Insights
# Baseline Fetal Heart Rate (LB): Mean and median values show the typical baseline fetal heart rate.
#
# Accelerations (AC): Visuals illustrate how fetal heart rate accelerations are distributed.
#
# Fetal Movements (FM): Data indicates the range and variability of fetal movements.
#
# Uterine Contractions (UC): Analyzing contractions helps understand their effects on fetal heart rate patterns.
#
# Decelerations (DL, DS, DP): Studying different types of decelerations and their frequencies provides important insights.
#
# Variability (ASTV, MSTV, ALTV, MLTV): Insights into short-term and long-term variability in fetal heart rate are provided.

# %% [markdown]
# ## Recommendations
# Time-Series Analysis: If we have data over time, we could look for trends and patterns in how fetal heart rates change.
#
# Clinical Implications: We should explore what the identified patterns and relationships mean for clinical practice and patient care.
#
# Predictive Models: There’s potential to create models that can predict outcomes based on the data we have, helping in future assessments and decision-making.
